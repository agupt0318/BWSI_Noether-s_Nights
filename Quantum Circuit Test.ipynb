# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit

n = 20

qr = QuantumRegister(n)
cr = ClassicalRegister(n)

qc = QuantumCircuit(qr, cr)

qc.h(qr[0:n])
qc.draw(output='mpl')

# %%
# ok I'll paste the code from visual studio because it outputs the visualization there
#also the dark side is not working lol

# %%
from qiskit import QuantumRegister, QuantumCircuit
from qiskit.circuit.library import C3XGate, C4XGate

qreg_key = QuantumRegister(10, 'key')
qreg_data = QuantumRegister(8, 'data')

circuit = QuantumCircuit(qreg_key, qreg_data)

circuit.cx(qreg_key[0], qreg_data[6])
circuit.cx(qreg_key[6], qreg_data[3])
circuit.cx(qreg_key[8], qreg_data[7])
circuit.cx(qreg_key[3], qreg_data[4])
circuit.cx(qreg_data[4], qreg_data[0])
circuit.append(C4XGate(), [qreg_data[3], qreg_data[4], qreg_data[6], qreg_data[7], qreg_data[0]])
circuit.ccx(qreg_data[6], qreg_data[7], qreg_data[0])
circuit.x(qreg_data[6])
circuit.x(qreg_data[7])
circuit.ccx(qreg_data[3], qreg_data[6], qreg_data[0])
circuit.ccx(qreg_data[6], qreg_data[7], qreg_data[1])
circuit.x(qreg_data[6])
circuit.append(C4XGate(), [qreg_data[3], qreg_data[4], qreg_data[6], qreg_data[7], qreg_data[1]])
circuit.x(qreg_data[3])
circuit.x(qreg_data[4])
circuit.x(qreg_data[7])
circuit.ccx(qreg_data[3], qreg_data[6], qreg_data[1])
circuit.ccx(qreg_data[4], qreg_data[6], qreg_data[1])
circuit.x(qreg_data[4])
circuit.x(qreg_data[3])
circuit.cx(qreg_key[0], qreg_data[6])
circuit.cx(qreg_key[6], qreg_data[3])
circuit.cx(qreg_key[3], qreg_data[4])
circuit.cx(qreg_key[8], qreg_data[7])
circuit.cx(qreg_key[2], qreg_data[4])
circuit.cx(qreg_key[5], qreg_data[3])
circuit.cx(qreg_key[9], qreg_data[6])
circuit.cx(qreg_key[7], qreg_data[7])
circuit.cx(qreg_data[4], qreg_data[2])
circuit.append(C3XGate(), [qreg_data[3], qreg_data[6], qreg_data[7], qreg_data[5]])
circuit.x(qreg_data[3])
circuit.x(qreg_data[4])
circuit.ccx(qreg_data[3], qreg_data[7], qreg_data[5])
circuit.ccx(qreg_data[3], qreg_data[7], qreg_data[2])
circuit.append(C4XGate(), [qreg_data[3], qreg_data[4], qreg_data[6], qreg_data[7], qreg_data[2]])
circuit.ccx(qreg_data[3], qreg_data[6], qreg_data[5])
circuit.x(qreg_data[7])
circuit.x(qreg_data[3])
circuit.x(qreg_data[6])
circuit.x(qreg_data[4])
circuit.ccx(qreg_data[3], qreg_data[6], qreg_data[2])
circuit.append(C3XGate(), [qreg_data[3], qreg_data[4], qreg_data[7], qreg_data[5]])
circuit.x(qreg_data[7])
circuit.x(qreg_data[6])
circuit.cx(qreg_key[2], qreg_data[4])
circuit.cx(qreg_key[5], qreg_data[3])
circuit.cx(qreg_key[9], qreg_data[6])
circuit.cx(qreg_key[7], qreg_data[7])

circuit.cx(qreg_key[5], qreg_data[5])
circuit.cx(qreg_key[7], qreg_data[0])
circuit.cx(qreg_key[1], qreg_data[1])
circuit.cx(qreg_key[6], qreg_data[2])

circuit.cx(qreg_data[2], qreg_data[6])
circuit.append(C4XGate(), [qreg_data[5], qreg_data[2], qreg_data[0], qreg_data[1], qreg_data[6]])
circuit.ccx(qreg_data[0], qreg_data[1], qreg_data[6])
circuit.x(qreg_data[0])
circuit.ccx(qreg_data[0], qreg_data[1], qreg_data[6])

circuit.x(qreg_data[5])
circuit.ccx(qreg_data[0], qreg_data[5], qreg_data[3])
circuit.x(qreg_data[0])
circuit.append(C4XGate(), [qreg_data[5], qreg_data[2], qreg_data[0], qreg_data[1], qreg_data[3]])
circuit.x(qreg_data[1])
circuit.x(qreg_data[2])
circuit.x(qreg_data[5])
circuit.ccx(qreg_data[0], qreg_data[1], qreg_data[3])
circuit.ccx(qreg_data[0], qreg_data[2], qreg_data[3])
circuit.x(qreg_data[2])
circuit.x(qreg_data[1])

circuit.cx(qreg_key[4], qreg_data[2])
circuit.cx(qreg_key[7], qreg_data[0])
circuit.cx(qreg_key[2], qreg_data[1])
circuit.cx(qreg_key[4], qreg_data[2])
circuit.cx(qreg_key[9], qreg_data[5])
circuit.cx(qreg_key[1], qreg_data[2])
circuit.cx(qreg_key[0], qreg_data[1])

circuit.append(C3XGate(), [qreg_data[1], qreg_data[0], qreg_data[5], qreg_data[7]])
circuit.x(qreg_data[1])
circuit.cx(qreg_data[2], qreg_data[4])
circuit.x(qreg_data[2])
circuit.ccx(qreg_data[1], qreg_data[5], qreg_data[7])
circuit.ccx(qreg_data[1], qreg_data[5], qreg_data[4])
circuit.append(C4XGate(), [qreg_data[5], qreg_data[0], qreg_data[1], qreg_data[2], qreg_data[4]])
circuit.ccx(qreg_data[0], qreg_data[1], qreg_data[7])
circuit.x(qreg_data[0])
circuit.x(qreg_data[1])
circuit.x(qreg_data[5])
circuit.x(qreg_data[2])
circuit.ccx(qreg_data[0], qreg_data[1], qreg_data[4])
circuit.cx(qreg_key[9], qreg_data[5])
circuit.append(C3XGate(), [qreg_data[5], qreg_data[1], qreg_data[2], qreg_data[7]])
circuit.x(qreg_data[0])
circuit.x(qreg_data[5])

circuit.cx(qreg_key[1], qreg_data[2])
circuit.cx(qreg_key[0], qreg_data[1])
circuit.cx(qreg_key[8], qreg_data[0])

circuit.swap(qreg_data[0], qreg_data[6])
circuit.swap(qreg_data[1], qreg_data[3])
circuit.swap(qreg_data[2], qreg_data[4])

circuit.swap(qreg_data[5], qreg_data[7])

circuit.draw('mpl')
